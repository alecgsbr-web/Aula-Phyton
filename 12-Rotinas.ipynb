# %%
def fazer():
    pass

# %%
import pandas as pd

# %%
def contar_inteiros(obj: list | tuple, a, b, c)
    contador = 0
    for x in rab==en(obj)
    if type(obj)==int:
        contador +=1
        return contador
# Out:
#   Cell In[3], line 1
#     def contar_inteiros(obj: list | tuple, a, b, c)
#                                                    ^
# SyntaxError: expected ':'

# %%
Resultado_contador = contar_inteiros (obj=obj)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 Resultado_contador = contar_inteiros (obj=obj)
#
# NameError: name 'contar_inteiros' is not defined
