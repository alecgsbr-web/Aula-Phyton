# %% [markdown]
# # Exercício:

# %% [markdown]
# ## Importe o .csv utilizado no exercício 7 da aula 11 e instancie um objeto da classe DataFrame. Considere que não à uma ordem entre os genes.
# Como inserir  na DataFrame uma tabela de frequência do número de caracteres no nome dos genes? Uma vez inserida, como obter um gráfico de barras deste dado?

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
listex4 = pd.read_csv("df.csv", index_col="Unnamed: 0")
freq = listex4["num_Caracteres"].value_counts()
listex4["freq_num_caracteres"] = listex4["num_Caracteres"].map(freq)
listex4 = listex4[["num_Caracteres", "freq_num_caracteres", "Iniciais", "Count_A", "tem_hu"]]
freq = listex4["num_Caracteres"].value_counts().sort_index().to_frame(name="Freq Absol Simp")
freq.rename(columns={0: "Freq Absol Simp"}, inplace=True)
freq = freq.round(2)
freq
sns.set_palette('RdBu', 2) 
freq.plot.pie(y=freq.columns[0], autopct='%1.1f%%', figsize=(5, 5))
plt.title('Frequência de números de caracteres')
plt.show()
listex4
# Out:
#        num_Caracteres  freq_num_caracteres    Iniciais  Count_A  tem_hu
# PPARG               5                    3  ['P', 'P']        1   False
# ADRB2               5                    3  ['A', 'D']        1   False
# DMT2                4                    2  ['D', 'M']        0   False
# FABP2               5                    3  ['F', 'A']        1   False
# MCR4                4                    2  ['M', 'C']        0   False

# %% [markdown]
# ## 01 – Descreva o racional da sua resposta:

# %% [markdown]
# R.: Criei um objeto chamado freq que calculava a a frequência com que cada valor de num_caracteres aparecia, adicionei ele no meu DataFrame como uma nova coluna. (Depois tentei plotar o gráfico somente com .iloc e não consegui). Então eu criei um novo data frame com as informações de freq e nomeei a coluna com as frequências de "Freq Absol Simp". Arredondei os valores (somente porque os valores tinham sido arredondados no exemplo que foi dado na aula), e plotei o gráfico de pizza.

# %% [markdown]
# ## 02 – Desenhe o fluxograma da resposta:

# %% [markdown]
# ## 03 – Escreva o programa em Python:

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
listex4 = pd.read_csv("df.csv", index_col="Unnamed: 0")
freq = listex4["num_Caracteres"].value_counts()
listex4["freq_num_caracteres"] = listex4["num_Caracteres"].map(freq)
listex4 = listex4[["num_Caracteres", "freq_num_caracteres", "Iniciais", "Count_A", "tem_hu"]]
freq = listex4["num_Caracteres"].value_counts().sort_index().to_frame(name="Freq Absol Simp")
freq.rename(columns={0: "Freq Absol Simp"}, inplace=True)
freq = freq.round(2)
freq
sns.set_palette('RdBu', 2) 
freq.plot.pie(y=freq.columns[0], autopct='%1.1f%%', figsize=(5, 5))
plt.title('Frequência de números de caracteres')
plt.show()
listex4
# Out:
#        num_Caracteres  freq_num_caracteres    Iniciais  Count_A  tem_hu
# PPARG               5                    3  ['P', 'P']        1   False
# ADRB2               5                    3  ['A', 'D']        1   False
# DMT2                4                    2  ['D', 'M']        0   False
# FABP2               5                    3  ['F', 'A']        1   False
# MCR4                4                    2  ['M', 'C']        0   False

# %% [markdown]
# ## Importe o .csv utilizado no exercício 7 da aula 11 e instancie um objeto da classe DataFrame. Considere que à uma ordem entre os genes.
# Como inserir  na DataFrame uma tabela de frequência do número de caracteres no nome dos genes? Uma vez inserida, como obter um gráfico de barras deste dado?

# %%
listex4["num_Caracteres"].plot(kind="bar")

plt.xlabel("Genes")
plt.ylabel("Número de caracteres")
plt.title("Número de caracteres por gene")
plt.bar(listex4.index, listex4["num_Caracteres"],
        color=["yellow", "orange", "red", "purple", "blue"])
plt.xticks(rotation=45)
plt.show()


print(freq)
freq.plot(kind="bar",  color="blue")
plt.xlabel("Número de caracteres")
plt.ylabel("Frequência Simples")
plt.title("Frequência Simples do Número de Caracteres")
plt.xticks(rotation=0)
plt.show()

freq2 = listex4["num_Caracteres"].value_counts().sort_index().cumsum().to_frame(name="Freq Absol Acum")
freq2.plot(kind="bar",  color="pink")
plt.xlabel("Número de caracteres")
plt.ylabel("Frequência Acumulada")
plt.title("Frequência Acumulada do número de caracteres")
plt.xticks(rotation=0)
plt.show()
# Out:
#                 Freq Absol Simp
# num_Caracteres
# 4                             2
# 5                             3

# %% [markdown]
# ## 04 – Descreva o racional da sua resposta:

# %% [markdown]
# R.: Como já tinha o DataFrame com as frequências, utilizei somente ele para criar um gráfico de barras com os dados, no entanto dessa forma os nomes dos genes não apareciam, então refiz plotando um gráfico de barras com num_Caracteres.

# %% [markdown]
# ## 05 – Desenhe o fluxograma da resposta:

# %% [markdown]
# ## 06 – Escreva o programa em Python:

# %%
listex4["num_Caracteres"].plot(kind="bar")

plt.xlabel("Genes")
plt.ylabel("Número de caracteres")
plt.title("Número de caracteres por gene")
plt.bar(listex4.index, listex4["num_Caracteres"],
        color=["yellow", "orange", "red", "purple", "blue"])
plt.xticks(rotation=45)
plt.show()


print(freq)
freq.plot(kind="bar",  color="blue")
plt.xlabel("Número de caracteres")
plt.ylabel("Frequência Simples")
plt.title("Frequência Simples do Número de Caracteres")
plt.xticks(rotation=0)
plt.show()

freq2 = listex4["num_Caracteres"].value_counts().sort_index().cumsum().to_frame(name="Freq Absol Acum")
freq2.plot(kind="bar",  color="pink")
plt.xlabel("Número de caracteres")
plt.ylabel("Frequência Acumulada")
plt.title("Frequência Acumulada do número de caracteres")
plt.xticks(rotation=0)
plt.show()
# Out:
#                 Freq Absol Simp
# num_Caracteres
# 4                             2
# 5                             3

# %% [markdown]
# ## 07 – Reorganize a DataFrame, removendo as colunas contendo os dois primeiros caracteres, o número de caracter 'a', e a presença de 'hu', dos genes. Renomeie as colunas de acordo com as informações. Adicione uma coluna com a informação de 'Amostra 1'.

# %%
listex4 = pd.read_csv("df.csv", index_col="Unnamed: 0")
freq = listex4["num_Caracteres"].value_counts()
listex4["freq_num_caracteres"] = listex4["num_Caracteres"].map(freq)
listex4 = listex4[["num_Caracteres", "freq_num_caracteres", "Iniciais", "Count_A", "tem_hu"]]
dfex7 = listex4[["num_Caracteres", "freq_num_caracteres"]]
dfex7["Amostra_1"] = np.random.randint(1,5,5)
dfex7
# Out:
# C:\Users\amand\AppData\Local\Temp\ipykernel_3012\3433496169.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfex7["Amostra_1"] = np.random.randint(1,5,5)
#        num_Caracteres  freq_num_caracteres  Amostra_1
# PPARG               5                    3          3
# ADRB2               5                    3          1
# DMT2                4                    2          1
# FABP2               5                    3          1
# MCR4                4                    2          4

# %% [markdown]
# ## 08 – Usando a função randint(), da classe random do módulo numpy (np.random.randint(1,10,5)), instancie objeto da classe numpy array. Calcule as frequências desta nova amostra, considerando que à uma ordem entre os genes. Insira na DataFrame este objeto como "Amostra 2".

# %%
dfex7["Amostra_2"] = np.random.randint(1,10,5)
print(dfex7)
freq3 = dfex7["Amostra_2"].value_counts().sort_index().to_frame(name="Freq Absol Simp")
cores = plt.cm.plasma(np.linspace(0, 1, len(freq3)))
plt.bar(freq3.index, freq3["Freq Absol Simp"], color=cores)
plt.xlabel("Amostra")
plt.ylabel("Frequência Simples")
plt.title("Frequência Simples da Amostra 2")
plt.xticks(rotation=0)
plt.show()
# Out:
# C:\Users\amand\AppData\Local\Temp\ipykernel_3012\3130337451.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfex7["Amostra_2"] = np.random.randint(1,10,5)
#        num_Caracteres  freq_num_caracteres  Amostra_1  Amostra_2
# PPARG               5                    3          3          4
# ADRB2               5                    3          1          8
# DMT2                4                    2          1          6
# FABP2               5                    3          1          6
# MCR4                4                    2          4          3

# %%
freq4 = dfex7["Amostra_2"].value_counts().sort_index().cumsum().to_frame(name="Freq Absol Acum")
freq4.plot(kind="bar")
plt.xlabel("Amostra")
plt.ylabel("Frequência Acumulada")
plt.title("Frequência Acumulada da Amostra 2")
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ## 09 – Repita o exercício 8, inserindo na DataFrame as replicas "Amostra 3“, "Amostra 4“, "Amostra 5“ e "Amostra 6".

# %%
dfex7["Amostra_3"] = np.random.randint(1,10,5)
dfex7["Amostra_4"] = np.random.randint(1,10,5)
dfex7["Amostra_5"] = np.random.randint(1,10,5)
dfex7["Amostra_6"] = np.random.randint(1,10,5)
print(dfex7)
# Out:
#        num_Caracteres  freq_num_caracteres  Amostra_1  Amostra_2  Amostra_3  \
# PPARG               5                    3          3          4          5
# ADRB2               5                    3          1          8          8
# DMT2                4                    2          1          6          1
# FABP2               5                    3          1          6          6
# MCR4                4                    2          4          3          9
#
#        Amostra_4  Amostra_5  Amostra_6
# PPARG          2          7          1
# ADRB2          8          9          1
# DMT2           9          7          2
# FABP2          6          9          4
# MCR4           7          3          9

# %%
def plot_frequencias(df, coluna):
    # Frequência absoluta simples
    freq_simples = df[coluna].value_counts().sort_index().to_frame(name="Freq Absol Simp")
    cores_simples = plt.cm.inferno(np.linspace(0, 1, len(freq_simples)))

    plt.bar(freq_simples.index, freq_simples["Freq Absol Simp"], color=cores_simples)
    plt.xlabel("Amostra")
    plt.ylabel("Frequência Simples")
    plt.title(f"Frequência Simples da {coluna}")
    plt.xticks(rotation=0)
    plt.show()

    # Frequência absoluta acumulada - mais recomendado para dados ordinais 
    freq_acum = df[coluna].value_counts().sort_index().cumsum().to_frame(name="Freq Absol Acum")
    cores_acum = plt.cm.viridis(np.linspace(0, 1, len(freq_acum)))

    plt.bar(freq_acum.index, freq_acum["Freq Absol Acum"], color=cores_acum)
    plt.xlabel("Amostra")
    plt.ylabel("Frequência Acumulada")
    plt.title(f"Frequência Acumulada da {coluna}")
    plt.xticks(rotation=0)
    plt.show()
plot_frequencias(dfex7, "Amostra_3")

# %%
plot_frequencias(dfex7, "Amostra_4")

# %%
plot_frequencias(dfex7, "Amostra_5")

# %%
plot_frequencias(dfex7, "Amostra_6")

# %% [markdown]
# ## 10 – Obtenha dos seus dados o gráfico abaixo, adicionando 3 replicas.

# %%
dfex7["Amostra_7"] = np.random.randint(1,10,5)
dfex7["Amostra_8"] = np.random.randint(1,10,5)
dfex7["Amostra_9"] = np.random.randint(1,10,5)
dfex7
# Out:
#        num_Caracteres  freq_num_caracteres  Amostra_1  Amostra_2  Amostra_3  \
# PPARG               5                    3          3          4          5
# ADRB2               5                    3          1          8          8
# DMT2                4                    2          1          6          1
# FABP2               5                    3          1          6          6
# MCR4                4                    2          4          3          9
#
#        Amostra_4  Amostra_5  Amostra_6  Amostra_7  Amostra_8  Amostra_9
# PPARG          2          7          1          5          2          7
# ADRB2          8          9          1          7          7          7
# DMT2           9          7          2          8          4          8
# FABP2          6          9          4          7          7          1
# MCR4           7          3          9          2          2          2

# %%
amostras = ["Amostra_7", "Amostra_8", "Amostra_9"]

df_long = dfex7.melt(
    value_vars=amostras,
    var_name="Amostra",
    value_name="Valor"
)
freq = (
    df_long
    .value_counts(["Amostra", "Valor"])
    .rename("Freq Absol Simp")
    .reset_index()
    .sort_values(["Amostra", "Valor"])
)
freq["Freq Absol Acum"] = freq.groupby("Amostra")["Freq Absol Simp"].cumsum()
sns.catplot(
    kind='bar',
    x='Valor',
    y='Freq Absol Acum',
    hue='Amostra',
    data=freq,
    errorbar='sd'
)
plt.xlabel("Dado")
plt.ylabel("Frequência acumulada")
plt.title("Frequência das amostras")

plt.show()
