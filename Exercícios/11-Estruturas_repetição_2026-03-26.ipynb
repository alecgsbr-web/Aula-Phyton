# %% [markdown]
# # Exercício:

# %% [markdown]
# ## Instancie um objeto da classe lista contendo 5.000 valores inteiros iniciando em 0.
# Quantos são pares e quantos são impares?

# %%
list1 = list(range(5000))
impares = sum([1 for x in list1 if x % 2 != 0])
print (impares)
# Out:
# 2500

# %% [markdown]
# ## 01 – Descreva o racional da sua resposta:

# %% [markdown]
# R.: Primeiro foi feita uma lista de 5000 números, em seguida foi definido uma lista denominado impares, depois foi definido que x eram os números que quando dívididos por 2 tinham um resultado diferente de zero, e a cada um desses números foi atribuído o valor de 1. Em seguida os números foram somados utilizando o método sum() e o resultado é o número de valores ímpares.

# %% [markdown]
# ## 02 – Desenhe o fluxograma da resposta:

# %% [markdown]
# <img src="./img/Diagrama_11_2.png" width="400" />

# %% [markdown]
# ## 03 – Escreva o programa em Python:

# %%
list1 = list(range(5000))
impares = sum([1 for x in list1 if x % 2 != 0])
print (impares)
# Out:
# 2500

# %% [markdown]
# ## 04 – Substitua a estrutura de repetição e responda novamente a pergunta anterior.

# %%
list4 = len(list(filter(lambda x: x % 2 != 0, list1)))
list4
# Out:
# 2500

# %% [markdown]
# ## Importe o .csv exportado na última aula e instancie um objeto da classe DataFrame.
#
# Dos números de letras nos genes, quais são pares e quantos são impares?

# %%
import pandas as pd
import numpy as np
listex4 = pd.read_csv("df.csv", index_col="Unnamed: 0")
df1 = pd.DataFrame (listex4.iloc[:,0])
df1
impares = sum([1 for x in df1.values.flatten() if x % 2 != 0])
pares = sum([1 for x in df1.values.flatten() if x % 2 == 0])
print(impares)
print(pares)
# Out:
# 3
# 2

# %% [markdown]
# ## 05 – Descreva o racional da sua resposta:

# %% [markdown]
# R.: Primeiro foi instanciado um DataFrame denominado listex4 contendo os dados desejados, em seguida foi feita uma máscara para selecionar somente a coluna num_caracteres. Depois foi aplicada a mesma lógica que no primiero exercício, mas somente nos valores de df1. Foi definido uma lista denominado impares, depois foi definido que x eram os números que quando dívididos por 2 tinham um resultado diferente de zero, e a cada um desses números foi atribuído o valor de 1. Em seguida os números foram somados utilizando o método sum() e o resultado é o número de valores ímpares. O mesmo foi feito para números pares, mas definindo que x seriam os números que divididos por 2 davam resultado igual a zero.

# %% [markdown]
# ## 06 – Desenhe o fluxograma da resposta:

# %% [markdown]
# <img src="./img/Diagrama_11_6.png" width="400" />

# %% [markdown]
# ## 07 – Escreva o programa em Python:

# %%
import pandas as pd
import numpy as np
# Importa o arquivo CSV
listex4 = pd.read_csv("df.csv", index_col="Unnamed: 0")
# Seleciona a primeira coluna como DataFrame
df1 = pd.DataFrame(listex4.iloc[:, 0])
# Verifica a DataFrame
print(df1)
# Conta números ímpares e pares
valores = df1.values.flatten()
impares = sum([1 for x in df1.values.flatten() if x % 2 != 0])
pares = sum([1 for x in df1.values.flatten() if x % 2 == 0])
# Exibe os resultados
print("Quantidade de ímpares:", impares)
print("Quantidade de pares:", pares)
# Out:
#         num_Caracteres
# PPARG                5
# ADRB2                5
# TCF7L2               6
# FABP2                5
# NOTCH2               6
# Quantidade de ímpares: 3
# Quantidade de pares: 2

# %% [markdown]
# ## 08 – Substitua a estrutura de repetição e responda novamente a pergunta anterior.

# %%
import pandas as pd
import numpy as np
listex4 = pd.read_csv("df.csv", index_col="Unnamed: 0")
df1 = pd.DataFrame (listex4.iloc[:,0])
df1
impares = len(list(filter(lambda x: x % 2 != 0, df1.values.flatten())))
pares = len(list(filter(lambda x: x % 2 == 0, df1.values.flatten())))
print(impares)
print(pares)
# Out:
# 3
# 2

# %% [markdown]
# ## 09 – Usando a coluna de presença de hu no nome do gene, itere os index deste objeto usando a função enumerate(). Estes index podem ser usados para imprimir cada um dos valores presentes na coluna dos dois primeiros caracteres dos nomes dos genes?

# %%
for i, tem_hu in enumerate(listex4["tem_hu"]):
    print(listex4["Iniciais"].iloc[i])
# Out:
# ['P', 'P']
# ['A', 'D']
# ['T', 'C']
# ['F', 'A']
# ['N', 'O']

# %% [markdown]
# ## 10 – Selecione qualquer uma das instâncias contidas na DataFrame. É possível recuperar as chaves e os valores com ao menos 3 estruturas de repetição diferentes?

# %%
#Selecionando o indice ADRB2
ADRB2 = listex4.loc["ADRB2"]
for chave in ADRB2.index:
    print(chave, ADRB2[chave])

for i, chave in enumerate(ADRB2.index):
    print(chave, ADRB2.iloc[i])

for chave, valor in zip(ADRB2.index, ADRB2.values):
    print(chave, valor)
# Out:
# num_Caracteres 5
# Iniciais ['A', 'D']
# Count_A 1
# tem_hu False
# num_Caracteres 5
# Iniciais ['A', 'D']
# Count_A 1
# tem_hu False
# num_Caracteres 5
# Iniciais ['A', 'D']
# Count_A 1
# tem_hu False
