# %%
lampada = "ligada"
bocal = "queimada"
conta = "não paga"


if lampada == "ligada":
    if bocal == "queimado":
        print("Substitua o bocal!")
    else:
       print ("Compre uma nova lâmpada")
else:
    print("Ligue a lâmpada!")
# Out:
# Compre uma nova lâmpada

# %%
lampada = "ligada"
lampada.__getattribute__
lampada.upper()
def desligar(lampada: str) -> str:
    lampada = "desligada"
    return lampada
desligar(lampada)
# Out:
# 'desligada'

# %%
bocal = "normal"
bocal.__getattribute__
bocal.upper
def queimar(bocal: str) -> str:
    bocal = "queimado"
    return bocal
queimar(bocal)
bocal.count("n")
# Out:
# 1

# %%
sequencia_gene = "ACTGGGUAUGAATTGCGCTTAGACTGGGUAUGAATTGCG"
sequencia_gene.count("AUG")
# Out:
# 3

# %%
Tupla = (11, 34, 67, 87, 90)
Tupla
type(Tupla)
# Out:
# tuple
